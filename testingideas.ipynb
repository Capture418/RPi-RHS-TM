# %%
import geopandas as gpd
import pandas as pd

# %%
FILENAME1 = 'World Energy Data.csv'
FILENAME2 = 'countries.geojson'

df_WED = gpd.read_file(FILENAME)

df_WED.head()
# Out:
#      field_1                   field_2                   field_3  \
# 0    Country                   Product                      Flow
# 1  Australia  Coal, peat and oil shale           Production (PJ)
# 2  Australia  Coal, peat and oil shale              Imports (PJ)
# 3  Australia  Coal, peat and oil shale              Exports (PJ)
# 4  Australia  Coal, peat and oil shale  Total energy supply (PJ)
#
#          field_4                       field_5                       field_6  \
# 0      NoCountry                     NoProduct                        NoFlow
# 1  01. Australia  01. Coal, peat and oil shale           01. Production (PJ)
# 2  01. Australia  01. Coal, peat and oil shale              02. Imports (PJ)
# 3  01. Australia  01. Coal, peat and oil shale              03. Exports (PJ)
# 4  01. Australia  01. Coal, peat and oil shale  04. Total energy supply (PJ)
#
#   field_7 field_8 field_9 field_10  ... field_48 field_49 field_50 field_51  \
# 0    1971    1972    1973     1974  ...     2012     2013     2014     2015
# 1    1368    1648    1685     1640  ...    10272    11075    11951    12501
# 2       0       0       0        0  ...        4        3        5        7
# 3    -541    -615    -739     -745  ...    -8171    -9101   -10167   -10634
# 4     884     923     946      928  ...     1969     1831     1737     1797
#
#   field_52 field_53 field_54 field_55          field_56 geometry
# 0     2016     2017     2018     2019  2020 Provisional     None
# 1    12224    12264    12035    12596             12332     None
# 2        7        8       13       17                20     None
# 3   -10553   -10248   -10333   -10629            -10541     None
# 4     1863     1872     1798     1744              1649     None
#
# [5 rows x 57 columns]

# %%
gdf = gpd.read_file(FILENAME2)
gdf.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>
